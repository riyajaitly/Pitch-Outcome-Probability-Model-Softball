# %%
import pandas as pd
df = pd.read_csv("Tritons_Pitches_2025.csv")

# %%
df
# Out:
#       tarantulaVideoHostedCFURL  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 6014                        NaN
# 6015                        NaN
# 6016                        NaN
# 6017                        NaN
# 6018                        NaN
#
#                                               playGuid     gameId  \
# 0      245239828-pix-6848d071b433a3bba65876f0-989-1007  245239828
# 1     245239828-pix-6848d071b433a3bba65876f0-1002-1020  245239828
# 2     245239828-pix-6848d071b433a3bba65876f0-1022-1041  245239828
# 3     245239828-pix-6848d071b433a3bba65876f0-1039-1058  245239828
# 4     245239828-pix-6848d071b433a3bba65876f0-1059-1076  245239828
# ...                                                ...        ...
# 6014  364528940-pix-67f423c8786af2bf10319b8b-6762-6775  364528940
# ...
